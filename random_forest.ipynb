# %%
import pandas as pd
import math

# %%
from datetime import datetime

import numpy as np

from pyspark.sql import SparkSession
from pyspark.sql.types import *
from pyspark.sql.functions import *
from pyspark.ml.feature import StringIndexer
from pyspark.ml.feature import OneHotEncoder
from pyspark.ml.feature import VectorAssembler
from pyspark.ml.classification import RandomForestClassifier
from pyspark.ml.evaluation import RegressionEvaluator

from pyspark.ml.evaluation import BinaryClassificationEvaluator
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
from pyspark.ml.tuning import CrossValidator
from pyspark.ml.tuning import ParamGridBuilder

# %%
spark = SparkSession.builder.config("spark.jars.packages", "org.mongodb.spark:mongo-spark-connector_2.12:3.0.2")\
                            .config("spark.network.timeout", "36000000s")\
                            .config("spark.executor.heartbeatInterval", "3600s")\
                            .getOrCreate()

# %% [markdown]
# ## Import Data from MongoDB Atlas

# %%
database = 'MongoDBAtlas'
collection_pos = 'pos_evals'
collection_elo = 'elo_eval'
user_name = 'Javier'
password = 'chess'
address = 'chesscluster.ar0uw.mongodb.net'
connection_string_pos = f"mongodb+srv://{user_name}:{password}@{address}/{database}.{collection_pos}"
connection_string_elo = f"mongodb+srv://{user_name}:{password}@{address}/{database}.{collection_elo}"

# %%
df_pos = spark.read.format("mongo").option("uri",connection_string_pos).load()
df_elo = spark.read.format("mongo").option("uri",connection_string_elo).load()

# %% [markdown]
# # Data Processing and Feature Engineering

# %%
df_elo = df_elo.withColumn('elo_diff',df_elo['Black Elo'] - df_elo['White Elo'])

# %%
def calculate_fide_expected_score(x):
    return math.erfc(-x / ((2000.0/7) * math.sqrt(2))) / 2 ## Formula that FIDE(Governing body of chess) uses to calculate expected score of a game.

xScore = udf(calculate_fide_expected_score, FloatType())

# %%
df_elo = df_elo.select('Black Elo', 'White Elo', 'Result', 'Time Class', 'Time Control','elo_diff',xScore("elo_diff").alias("expected_score_fide"))

# %%
def indexStringColumns(df, cols):
    # variable newdf will be updated several times
    newdf = df
    
    for c in cols:
        # For each given colum, fits StringIndexerModel.
        si = StringIndexer(inputCol=c, outputCol=c+"-num").setHandleInvalid("keep")
        sm = si.fit(newdf)
        
        # Creates a DataFame by putting the transformed values in the new colum with suffix "-num" 
        # and then drops the original columns.
        # and drop the "-num" suffix. 
        newdf = sm.transform(newdf).drop(c)
        newdf = newdf.withColumnRenamed(c+"-num", c)
    return newdf

def oneHotEncodeColumns(df, cols):
    newdf = df
    for c in cols:
        # For each given colum, create OneHotEncoder. 
        # dropLast : Whether to drop the last category in the encoded vector (default: true)
        ohe = OneHotEncoder(inputCol=c, outputCol=c+"-onehot", dropLast=False)
        ohe_model = ohe.fit(newdf)
        #Creates a DataFame by putting the transformed values in the new colum with suffix "-onehot" 
        #and then drops the original columns.
        #and drop the "-onehot" suffix. 
        newdf = ohe_model.transform(newdf).drop(c)
        newdf = newdf.withColumnRenamed(c+"-onehot", c)
    return newdf

# %%
categorical_cols = ["Time Class","Time Control"]
df_elo_str = indexStringColumns(df_elo, categorical_cols)

# %%
df_elo_ohe = oneHotEncodeColumns(df_elo_str, categorical_cols)

# %%
def convert_res_to_binary(x):
    if x == '1-0':
        return 1
    elif x == '0-1':
        return 0
    elif '5' in x:
        return 2

result_conv = udf(convert_res_to_binary, IntegerType())

# %%
df_elo = df_elo_ohe.withColumn('result_int',result_conv('Result'))

# %%
def convert_to_int(x):
    try:
        return int(x)
    except ValueError:
        return None
    
int_conv = udf(convert_to_int, IntegerType())

# %%
df_elo = df_elo.select(int_conv('Black Elo').alias('Black Elo'), int_conv('White Elo').alias('White Elo'), 'Result', 'elo_diff', 'expected_score_fide', 'Time Class', 'Time Control', 'result_int')

# %%
df_elo = df_elo.where(df_elo.result_int != 2)

# %%
df_elo.show()
# Out:
# +---------+---------+------+--------+-------------------+-------------+--------------+----------+
# |Black Elo|White Elo|Result|elo_diff|expected_score_fide|   Time Class|  Time Control|result_int|
# +---------+---------+------+--------+-------------------+-------------+--------------+----------+
# |     2350|     2500|   1-0|  -150.0|          0.2997916|(5,[2],[1.0])|(27,[4],[1.0])|         1|
# |     2646|     2331|   0-1|   315.0|          0.8648778|(5,[2],[1.0])|(27,[4],[1.0])|         0|
# |     2287|     2317|   0-1|   -30.0|          0.4581879|(5,[2],[1.0])|(27,[4],[1.0])|         0|
# |     2440|     2406|   1-0|    34.0|          0.5473623|(5,[2],[1.0])|(27,[4],[1.0])|         1|
# |     2386|     2544|   1-0|  -158.0|         0.29013172|(5,[2],[1.0])|(27,[4],[1.0])|         1|
# |     2778|     2746|   1-0|    32.0|         0.54458827|(5,[0],[1.0])|(27,[0],[1.0])|         1|
# |     2646|     2736|   0-1|   -90.0|         0.37638083|(5,[0],[1.0])|(27,[0],[1.0])|         0|
# |     2767|     2665|   1-0|   102.0|          0.6394541|(5,[0],[1.0])|(27,[0],[1.0])|         1|
# |     2785|     2637|   0-1|   148.0|          0.6977709|(5,[0],[1.0])|(27,[0],[1.0])|         0|
# |     2748|     2805|   1-0|   -57.0|          0.4209358|(5,[0],[1.0])|(27,[0],[1.0])|         1|
# |     2771|     2878|   1-0|  -107.0|         0.35401618|(5,[0],[1.0])|(27,[0],[1.0])|         1|
# |     2868|     2781|   1-0|    87.0|          0.6196265|(5,[0],[1.0])|(27,[0],[1.0])|         1|
# |     2864|     2785|   0-1|    79.0|         0.60891795|(5,[0],[1.0])|(27,[0],[1.0])|         0|
# |     2748|     2909|   1-0|  -161.0|         0.28654724|(5,[0],[1.0])|(27,[8],[1.0])|         1|
# |     2908|     2761|   0-1|   147.0|         0.69654876|(5,[0],[1.0])|(27,[8],[1.0])|         0|
# |     2625|     2417|   0-1|   208.0|         0.76669323|(5,[2],[1.0])|(27,[4],[1.0])|         0|
# |     2529|     2453|   1-0|    76.0|          0.6048804|(5,[2],[1.0])|(27,[4],[1.0])|         1|
# |     2514|     2770|   1-0|  -256.0|         0.18512638|(5,[0],[1.0])|(27,[2],[1.0])|         1|
# |     2772|     2431|   0-1|   341.0|          0.8836632|(5,[0],[1.0])|(27,[2],[1.0])|         0|
# |     2767|     2926|   1-0|  -159.0|         0.28893456|(5,[0],[1.0])|(27,[2],[1.0])|         1|
# +---------+---------+------+--------+-------------------+-------------+--------------+----------+
# only showing top 20 rows

# %%
va = VectorAssembler(outputCol="features", inputCols=["Black Elo", "White Elo", "elo_diff", "Time Class", "Time Control"])
va_df = va.transform(df_elo).select("features", "result_int").withColumnRenamed("result_int", "label")

# %% [markdown]
# ## Random Forest

# %%
va_df.show(1, truncate=False)
# Out:
# +------------------------------------------------+-----+
# |features                                        |label|
# +------------------------------------------------+-----+
# |(35,[0,1,2,5,12],[2350.0,2500.0,-150.0,1.0,1.0])|1    |
# +------------------------------------------------+-----+
# only showing top 1 row

# %%
splits = va_df.randomSplit([0.8, 0.2])

train = splits[0].cache()
validation = splits[1].cache()

# %%
rf = RandomForestClassifier(maxDepth=25)

# %%
rf_model = rf.fit(train)

# %%
rf_model.featureImportances
# Out:
# Out[23]: SparseVector(35, {0: 0.1827, 1: 0.137, 2: 0.6033, 3: 0.006, 4: 0.0047, 5: 0.0068, 6: 0.0023, 8: 0.0068, 9: 0.0053, 10: 0.0092, 11: 0.0054, 12: 0.0039, 13: 0.0049, 14: 0.0013, 15: 0.0065, 16: 0.0021, 17: 0.0016, 18: 0.0018, 19: 0.0023, 20: 0.001, 21: 0.0013, 23: 0.0004, 24: 0.0001, 25: 0.0007, 26: 0.0008, 27: 0.0001, 29: 0.0002, 30: 0.0007, 32: 0.0008})

# %%
print(rf_model.toDebugString)
# Out:
# RandomForestClassificationModel: uid=RandomForestClassifier_9e39c7e3a3d9, numTrees=20, numClasses=2, numFeatures=35
#   Tree 0 (weight 1.0):
#     If (feature 5 in {1.0})
#      If (feature 2 <= 20.5)
#       If (feature 2 <= -97.5)
#        Predict: 1.0
#       Else (feature 2 > -97.5)
#        If (feature 1 <= 2474.5)
#         Predict: 1.0
#        Else (feature 1 > 2474.5)
#         If (feature 1 <= 2596.5)
#          Predict: 0.0
#         Else (feature 1 > 2596.5)
#          If (feature 12 in {1.0})
#           Predict: 0.0
#          Else (feature 12 not in {1.0})
#           Predict: 1.0
#      Else (feature 2 > 20.5)
#       Predict: 0.0
#     Else (feature 5 not in {1.0})
#      If (feature 29 in {1.0})
#       Predict: 1.0
#      Else (feature 29 not in {1.0})
#       If (feature 20 in {1.0})
#        If (feature 2 <= -349.5)
#         Predict: 1.0
#        Else (feature 2 > -349.5)
#         Predict: 0.0
#       Else (feature 20 not in {1.0})
#        If (feature 1 <= 2814.5)
#         If (feature 2 <= -9.5)
#          If (feature 0 <= 1433.5)
#           If (feature 19 in {1.0})
#            Predict: 1.0
#           Else (feature 19 not in {1.0})
#            If (feature 4 in {1.0})
#             Predict: 1.0
#            Else (feature 4 not in {1.0})
#             If (feature 1 <= 1145.5)
#              Predict: 1.0
#             Else (feature 1 > 1145.5)
#              If (feature 0 <= 1146.5)
#               If (feature 2 <= -349.5)
#                Predict: 0.0
#               Else (feature 2 > -349.5)
#                Predict: 1.0
#              Else (feature 0 > 1146.5)
#               Predict: 1.0
#          Else (feature 0 > 1433.5)
#           If (feature 0 <= 2697.5)
#            If (feature 3 in {0.0})
#             If (feature 6 in {1.0})
#              Predict: 1.0
#             Else (feature 6 not in {1.0})
#              If (feature 0 <= 2353.5)
#               Predict: 1.0
#              Else (feature 0 > 2353.5)
#               If (feature 1 <= 2513.5)
#                If (feature 1 <= 2439.5)
#                 Predict: 1.0
#                Else (feature 1 > 2439.5)
#                 Predict: 0.0
#               Else (feature 1 > 2513.5)
#                Predict: 1.0
#            Else (feature 3 not in {0.0})
#             Predict: 1.0
#           Else (feature 0 > 2697.5)
#            If (feature 8 in {0.0})
#             Predict: 1.0
#            Else (feature 8 not in {0.0})
#             If (feature 2 <= -64.5)
#              If (feature 2 <= -97.5)
#               Predict: 0.0
#              Else (feature 2 > -97.5)
#               Predict: 1.0
#             Else (feature 2 > -64.5)
#              Predict: 1.0
#         Else (feature 2 > -9.5)
#          If (feature 16 in {1.0})
#           Predict: 0.0
#          Else (feature 16 not in {1.0})
#           If (feature 19 in {1.0})
#            Predict: 0.0
#           Else (feature 19 not in {1.0})
#            If (feature 8 in {0.0})
#             If (feature 0 <= 2993.5)
#              If (feature 11 in {1.0})
#               Predict: 0.0
#              Else (feature 11 not in {1.0})
#               If (feature 0 <= 1146.5)
#                If (feature 3 in {0.0})
#                 Predict: 0.0
#                Else (feature 3 not in {0.0})
#                 Predict: 1.0
#               Else (feature 0 > 1146.5)
#                Predict: 0.0
#             Else (feature 0 > 2993.5)
#              Predict: 0.0
#            Else (feature 8 not in {0.0})
#             If (feature 1 <= 2142.0)
#              Predict: 0.0
#             Else (feature 1 > 2142.0)
#              If (feature 0 <= 2770.5)
#               Predict: 0.0
#              Else (feature 0 > 2770.5)
#               If (feature 2 <= 28.5)
#                If (feature 1 <= 2774.5)
#                 Predict: 0.0
#                Else (feature 1 > 2774.5)
#                 If (feature 1 <= 2801.5)
#                  Predict: 1.0
#                 Else (feature 1 > 2801.5)
#                  Predict: 0.0
#               Else (feature 2 > 28.5)
#                Predict: 0.0
#        Else (feature 1 > 2814.5)
#         If (feature 3 in {0.0})
#          Predict: 1.0
#         Else (feature 3 not in {0.0})
#          If (feature 8 in {0.0})
#           Predict: 1.0
#          Else (feature 8 not in {0.0})
#           If (feature 1 <= 2942.5)
#            If (feature 2 <= 4.5)
#             Predict: 1.0
#            Else (feature 2 > 4.5)
#             Predict: 0.0
#           Else (feature 1 > 2942.5)
#            If (feature 0 <= 3024.0)
#             If (feature 0 <= 2993.5)
#              Predict: 1.0
#             Else (feature 0 > 2993.5)
#              If (feature 1 <= 2995.5)
#               Predict: 1.0
#              Else (feature 1 > 2995.5)
#               Predict: 0.0
#            Else (feature 0 > 3024.0)
#             If (feature 1 <= 3128.5)
#              Predict: 0.0
#             Else (feature 1 > 3128.5)
#              Predict: 1.0
#   Tree 1 (weight 1.0):
#     If (feature 8 in {0.0})
#      If (feature 11 in {1.0})
#       If (feature 1 <= 2856.5)
#        Predict: 0.0
#       Else (feature 1 > 2856.5)
#        Predict: 1.0
#      Else (feature 11 not in {1.0})
#       If (feature 13 in {1.0})
#        Predict: 0.0
#       Else (feature 13 not in {1.0})
#        If (feature 19 in {1.0})
#         If (feature 0 <= 2353.5)
#          Predict: 1.0
#         Else (feature 0 > 2353.5)
#          Predict: 0.0
#        Else (feature 19 not in {1.0})
#         If (feature 2 <= 12.5)
#          If (feature 2 <= -97.5)
#           If (feature 0 <= 2839.5)
#            If (feature 2 <= -159.5)
#             If (feature 6 in {1.0})
#              Predict: 1.0
#             Else (feature 6 not in {1.0})
#              If (feature 12 in {1.0})
#               Predict: 1.0
#              Else (feature 12 not in {1.0})
#               If (feature 1 <= 2673.5)
#                Predict: 1.0
#               Else (feature 1 > 2673.5)
#                If (feature 0 <= 2697.5)
#                 Predict: 1.0
#                Else (feature 0 > 2697.5)
#                 If (feature 3 in {0.0})
#                  If (feature 1 <= 2920.5)
#                   If (feature 0 <= 2715.5)
#                    Predict: 0.0
#                   Else (feature 0 > 2715.5)
#                    Predict: 1.0
#                  Else (feature 1 > 2920.5)
#                   Predict: 1.0
#                 Else (feature 3 not in {0.0})
#                  Predict: 1.0
#            Else (feature 2 > -159.5)
#             Predict: 1.0
#           Else (feature 0 > 2839.5)
#            If (feature 4 in {1.0})
#             If (feature 0 <= 2852.5)
#              Predict: 0.0
#             Else (feature 0 > 2852.5)
#              Predict: 1.0
#            Else (feature 4 not in {1.0})
#             Predict: 0.0
#          Else (feature 2 > -97.5)
#           If (feature 10 in {1.0})
#            Predict: 0.0
#           Else (feature 10 not in {1.0})
#            If (feature 14 in {1.0})
#             Predict: 1.0
#            Else (feature 14 not in {1.0})
#             If (feature 2 <= 4.5)
#              If (feature 1 <= 1145.5)
#               Predict: 1.0
#              Else (feature 1 > 1145.5)
#               If (feature 18 in {1.0})
#                Predict: 1.0
#               Else (feature 18 not in {1.0})
#                If (feature 25 in {1.0})
#                 Predict: 1.0
#                Else (feature 25 not in {1.0})
#                 If (feature 3 in {1.0})
#                  Predict: 0.0
#                 Else (feature 3 not in {1.0})
#                  If (feature 2 <= -17.5)
#                   If (feature 5 in {1.0})
#                    If (feature 1 <= 2643.5)
#                     If (feature 1 <= 2596.5)
#                      Predict: 0.0
#                     Else (feature 1 > 2596.5)
#                      If (feature 2 <= -52.5)
#                       Predict: 1.0
#                      Else (feature 2 > -52.5)
#                       If (feature 15 in {0.0})
#                        If (feature 2 <= -32.5)
#                         Predict: 0.0
#                        Else (feature 2 > -32.5)
#                         Predict: 1.0
#                       Else (feature 15 not in {0.0})
#                        Predict: 1.0
#                    Else (feature 1 > 2643.5)
#                     Predict: 0.0
#                   Else (feature 5 not in {1.0})
#                    Predict: 1.0
#                  Else (feature 2 > -17.5)
#                   Predict: 0.0
#             Else (feature 2 > 4.5)
#              If (feature 0 <= 2738.5)
#               Predict: 1.0
#              Else (feature 0 > 2738.5)
#               If (feature 1 <= 2995.5)
#                Predict: 1.0
#               Else (feature 1 > 2995.5)
#                Predict: 0.0
#         Else (feature 2 > 12.5)
#          If (feature 0 <= 2895.5)
#           If (feature 1 <= 2774.5)
#            If (feature 0 <= 2143.0)
#             Predict: 0.0
#            Else (feature 0 > 2143.0)
#             If (feature 15 in {1.0})
#              Predict: 0.0
#             Else (feature 15 not in {1.0})
#              If (feature 10 in {1.0})
#               Predict: 0.0
#              Else (feature 10 not in {1.0})
#               If (feature 0 <= 2796.5)
#                If (feature 3 in {1.0})
#                 Predict: 0.0
#                Else (feature 3 not in {1.0})
#                 If (feature 17 in {1.0})
#                  If (feature 0 <= 2353.5)
#                   Predict: 0.0
#                  Else (feature 0 > 2353.5)
#                   Predict: 1.0
#                 Else (feature 17 not in {1.0})
#                  Predict: 0.0
#               Else (feature 0 > 2796.5)
#                If (feature 2 <= 243.5)
#                 Predict: 0.0
#                Else (feature 2 > 243.5)
#                 Predict: 1.0
#           Else (feature 1 > 2774.5)
#            Predict: 1.0
#          Else (feature 0 > 2895.5)
#           If (feature 16 in {1.0})
#            Predict: 0.0
#           Else (feature 16 not in {1.0})
#            If (feature 2 <= 90.5)
#             If (feature 2 <= 46.5)
#              If (feature 1 <= 2942.5)
#               Predict: 1.0
#              Else (feature 1 > 2942.5)
#               If (feature 0 <= 3024.0)
#                Predict: 0.0
#               Else (feature 0 > 3024.0)
#                If (feature 3 in {1.0})
#                 Predict: 1.0
#                Else (feature 3 not in {1.0})
#                 If (feature 2 <= 36.5)
#                  Predict: 0.0
#                 Else (feature 2 > 36.5)
#                  Predict: 1.0
#             Else (feature 2 > 46.5)
#              If (feature 10 in {0.0})
#               Predict: 0.0
#              Else (feature 10 not in {0.0})
#               Predict: 1.0
#            Else (feature 2 > 90.5)
#             Predict: 0.0
#     Else (feature 8 not in {0.0})
#      Predict: 1.0
#   Tree 2 (weight 1.0):
#     If (feature 0 <= 2895.5)
#      If (feature 2 <= -9.5)
#       If (feature 6 in {1.0})
#        Predict: 1.0
#       Else (feature 6 not in {1.0})
#        If (feature 10 in {1.0})
#         Predict: 1.0
#        Else (feature 10 not in {1.0})
#         If (feature 2 <= -32.5)
#          If (feature 1 <= 2142.0)
#           Predict: 1.0
#          Else (feature 1 > 2142.0)
#           If (feature 16 in {1.0})
#            If (feature 2 <= -136.5)
#             Predict: 1.0
#            Else (feature 2 > -136.5)
#             Predict: 0.0
#           Else (feature 16 not in {1.0})
#            If (feature 14 in {1.0})
#             Predict: 1.0
#            Else (feature 14 not in {1.0})
#             If (feature 0 <= 2143.0)
#              Predict: 1.0
#             Else (feature 0 > 2143.0)
#              If (feature 3 in {0.0})
#               If (feature 18 in {1.0})
#                Predict: 1.0
#               Else (feature 18 not in {1.0})
#                If (feature 1 <= 2474.5)
#                 Predict: 0.0
#                Else (feature 1 > 2474.5)
#                 If (feature 2 <= -97.5)
#                  If (feature 11 in {1.0})
#                   If (feature 1 <= 2968.5)
#                    Predict: 0.0
#                   Else (feature 1 > 2968.5)
#                    Predict: 1.0
#                  Else (feature 11 not in {1.0})
#                   Predict: 1.0
#                 Else (feature 2 > -97.5)
#                  If (feature 11 in {1.0})
#                   Predict: 1.0
#                  Else (feature 11 not in {1.0})
#                   If (feature 12 in {1.0})
#                    Predict: 0.0
#                   Else (feature 12 not in {1.0})
#                    If (feature 5 in {1.0})
#                     If (feature 0 <= 2673.5)
#                      Predict: 1.0
#                     Else (feature 0 > 2673.5)
#                      Predict: 0.0
#                    Else (feature 5 not in {1.0})
#                     Predict: 1.0
#              Else (feature 3 not in {0.0})
#               Predict: 1.0
#         Else (feature 2 > -32.5)
#          If (feature 5 in {1.0})
#           If (feature 0 <= 1146.5)
#            Predict: 1.0
#           Else (feature 0 > 1146.5)
#            Predict: 0.0
#          Else (feature 5 not in {1.0})
#           If (feature 13 in {1.0})
#            Predict: 0.0
#           Else (feature 13 not in {1.0})
#            If (feature 0 <= 2868.5)
#             If (feature 0 <= 2552.5)
#              If (feature 4 in {1.0})
#               Predict: 0.0
#              Else (feature 4 not in {1.0})
#               Predict: 1.0
#             Else (feature 0 > 2552.5)
#              Predict: 1.0
#            Else (feature 0 > 2868.5)
#             If (feature 8 in {1.0})
#              Predict: 0.0
#             Else (feature 8 not in {1.0})
#              Predict: 1.0
#      Else (feature 2 > -9.5)
#       If (feature 1 <= 2700.5)
#        If (feature 15 in {1.0})
#         Predict: 0.0
#        Else (feature 15 not in {1.0})
#         If (feature 4 in {1.0})
#          Predict: 0.0
#         Else (feature 4 not in {1.0})
#          If (feature 2 <= 28.5)
#           Predict: 0.0
#          Else (feature 2 > 28.5)
#           If (feature 27 in {1.0})
#            Predict: 0.0
#           Else (feature 27 not in {1.0})
#            If (feature 1 <= 2142.0)
#             Predict: 0.0
#            Else (feature 1 > 2142.0)
#             If (feature 10 in {1.0})
#              If (feature 1 <= 2643.5)
#               Predict: 0.0
#              Else (feature 1 > 2643.5)
#               If (feature 1 <= 2673.5)
#                If (feature 0 <= 2852.5)
#                 Predict: 1.0
#                Else (feature 0 > 2852.5)
#                 If (feature 2 <= 243.5)
#                  Predict: 0.0
#                 Else (feature 2 > 243.5)
#                  Predict: 1.0
#               Else (feature 1 > 2673.5)
#                If (feature 0 <= 2852.5)
#                 Predict: 1.0
#                Else (feature 0 > 2852.5)
#                 Predict: 0.0
#             Else (feature 10 not in {1.0})
#              If (feature 2 <= 155.5)
#               If (feature 0 <= 2471.5)
#                Predict: 1.0
#               Else (feature 0 > 2471.5)
#                If (feature 0 <= 2811.5)
#                 If (feature 13 in {1.0})
#                  Predict: 1.0
#                 Else (feature 13 not in {1.0})
#                  If (feature 0 <= 2595.5)
#                   Predict: 0.0
#                  Else (feature 0 > 2595.5)
#                   If (feature 1 <= 2673.5)
#                    If (feature 1 <= 2513.5)
#                     If (feature 1 <= 2474.5)
#                      Predict: 0.0
#                     Else (feature 1 > 2474.5)
#                      If (feature 2 <= 128.5)
#                       Predict: 0.0
#                      Else (feature 2 > 128.5)
#                       Predict: 1.0
#                    Else (feature 1 > 2513.5)
#                     If (feature 18 in {1.0})
#                      Predict: 1.0
#                     Else (feature 18 not in {1.0})
#                      If (feature 14 in {1.0})
#                       Predict: 0.0
#                      Else (feature 14 not in {1.0})
#                       If (feature 2 <= 128.5)
#                        If (feature 1 <= 2596.5)
#                         Predict: 1.0
#                        Else (feature 1 > 2596.5)
#                         Predict: 0.0
#                       Else (feature 2 > 128.5)
#                        If (feature 5 in {0.0})
#                         Predict: 0.0
#                        Else (feature 5 not in {0.0})
#                         If (feature 0 <= 2756.5)
#                          Predict: 0.0
#                         Else (feature 0 > 2756.5)
#                          Predict: 1.0
#                   Else (feature 1 > 2673.5)
#                    Predict: 0.0
#                Else (feature 0 > 2811.5)
#                 Predict: 0.0
#              Else (feature 2 > 155.5)
#               If (feature 14 in {1.0})
#                Predict: 1.0
#               Else (feature 14 not in {1.0})
#                Predict: 0.0
#       Else (feature 1 > 2700.5)
#        Predict: 0.0
#     Else (feature 0 > 2895.5)
#      If (feature 2 <= 28.5)
#       If (feature 2 <= -97.5)
#        Predict: 1.0
#       Else (feature 2 > -97.5)
#        If (feature 8 in {0.0})
#         If (feature 2 <= -79.5)
#          Predict: 0.0
#         Else (feature 2 > -79.5)
#          If (feature 16 in {1.0})
#           Predict: 0.0
#          Else (feature 16 not in {1.0})
#           Predict: 1.0
#        Else (feature 8 not in {0.0})
#         If (feature 0 <= 2993.5)
#          Predict: 1.0
#         Else (feature 0 > 2993.5)
#          If (feature 2 <= -9.5)
#           Predict: 0.0
#          Else (feature 2 > -9.5)
#           If (feature 2 <= 20.5)
#            Predict: 1.0
#           Else (feature 2 > 20.5)
#            Predict: 0.0
#      Else (feature 2 > 28.5)
#       If (feature 21 in {1.0})
#        Predict: 1.0
#       Else (feature 21 not in {1.0})
#        If (feature 1 <= 2789.5)
#         Predict: 0.0
#        Else (feature 1 > 2789.5)
#         If (feature 8 in {0.0})
#          Predict: 0.0
#         Else (feature 8 not in {0.0})
#          If (feature 2 <= 155.5)
#           If (feature 0 <= 3134.5)
#            If (feature 2 <= 128.5)
#             Predict: 0.0
#            Else (feature 2 > 128.5)
#             Predict: 1.0
#           Else (feature 0 > 3134.5)
#            Predict: 0.0
#          Else (feature 2 > 155.5)
#           Predict: 0.0
#   Tree 3 (weight 1.0):
#     If (feature 5 in {1.0})
#      If (feature 2 <= 28.5)
#       If (feature 1 <= 2673.5)
#        If (feature 1 <= 2643.5)
#         If (feature 1 <= 2513.5)
#          If (feature 0 <= 2471.5)
#           If (feature 14 in {0.0})
#            If (feature 1 <= 2366.5)
#             If (feature 2 <= -79.5)
#              Predict: 1.0
#             Else (feature 2 > -79.5)
#              Predict: 0.0
#            Else (feature 1 > 2366.5)
#             Predict: 1.0
#           Else (feature 14 not in {0.0})
#            Predict: 1.0
#          Else (feature 0 > 2471.5)
#           Predict: 1.0
#         Else (feature 1 > 2513.5)
#          If (feature 18 in {1.0})
#           Predict: 1.0
#          Else (feature 18 not in {1.0})
#           If (feature 12 in {0.0})
#            Predict: 1.0
#           Else (feature 12 not in {0.0})
#            If (feature 1 <= 2596.5)
#             If (feature 1 <= 2551.5)
#              If (feature 2 <= -97.5)
#               Predict: 1.0
#              Else (feature 2 > -97.5)
#               Predict: 0.0
#             Else (feature 1 > 2551.5)
#              If (feature 0 <= 2471.5)
#               Predict: 1.0
#              Else (feature 0 > 2471.5)
#               Predict: 0.0
#            Else (feature 1 > 2596.5)
#             Predict: 1.0
#        Else (feature 1 > 2643.5)
#         If (feature 18 in {0.0})
#          Predict: 0.0
#         Else (feature 18 not in {0.0})
#          Predict: 1.0
#       Else (feature 1 > 2673.5)
#        Predict: 1.0
#      Else (feature 2 > 28.5)
#       If (feature 1 <= 2513.5)
#        Predict: 0.0
#       Else (feature 1 > 2513.5)
#        If (feature 15 in {1.0})
#         Predict: 0.0
#        Else (feature 15 not in {1.0})
#         If (feature 12 in {0.0})
#          If (feature 1 <= 2643.5)
#           Predict: 0.0
#          Else (feature 1 > 2643.5)
#           Predict: 1.0
#         Else (feature 12 not in {0.0})
#          Predict: 1.0
#     Else (feature 5 not in {1.0})
#      If (feature 2 <= 28.5)
#       If (feature 0 <= 2697.5)
#        If (feature 13 in {1.0})
#         If (feature 0 <= 1146.5)
#          Predict: 1.0
#         Else (feature 0 > 1146.5)
#          If (feature 2 <= -1.5)
#           Predict: 1.0
#          Else (feature 2 > -1.5)
#           Predict: 0.0
#        Else (feature 13 not in {1.0})
#         If (feature 10 in {1.0})
#          Predict: 1.0
#         Else (feature 10 not in {1.0})
#          If (feature 1 <= 2596.5)
#           If (feature 23 in {1.0})
#            Predict: 1.0
#           Else (feature 23 not in {1.0})
#            If (feature 0 <= 2471.5)
#             Predict: 1.0
#            Else (feature 0 > 2471.5)
#             If (feature 0 <= 2595.5)
#              If (feature 1 <= 2474.5)
#               Predict: 1.0
#              Else (feature 1 > 2474.5)
#               If (feature 9 in {1.0})
#                If (feature 2 <= -17.5)
#                 Predict: 1.0
#                Else (feature 2 > -17.5)
#                 If (feature 2 <= -1.5)
#                  Predict: 0.0
#                 Else (feature 2 > -1.5)
#                  Predict: 1.0
#               Else (feature 9 not in {1.0})
#                Predict: 0.0
#             Else (feature 0 > 2595.5)
#              Predict: 0.0
#          Else (feature 1 > 2596.5)
#           If (feature 0 <= 2631.5)
#            Predict: 1.0
#           Else (feature 0 > 2631.5)
#            If (feature 9 in {1.0})
#             If (feature 2 <= -97.5)
#              Predict: 1.0
#             Else (feature 2 > -97.5)
#              Predict: 0.0
#            Else (feature 9 not in {1.0})
#             Predict: 1.0
#       Else (feature 0 > 2697.5)
#        If (feature 1 <= 2870.5)
#         If (feature 3 in {0.0})
#          If (feature 9 in {0.0})
#           If (feature 1 <= 2856.5)
#            Predict: 0.0
#           Else (feature 1 > 2856.5)
#            If (feature 0 <= 2868.5)
#             Predict: 0.0
#            Else (feature 0 > 2868.5)
#             Predict: 1.0
#          Else (feature 9 not in {0.0})
#           Predict: 1.0
#         Else (feature 3 not in {0.0})
#          If (feature 1 <= 2719.5)
#           Predict: 0.0
#          Else (feature 1 > 2719.5)
#           Predict: 1.0
#        Else (feature 1 > 2870.5)
#         If (feature 2 <= -159.5)
#          Predict: 1.0
#         Else (feature 2 > -159.5)
#          If (feature 0 <= 3024.0)
#           If (feature 0 <= 2756.5)
#            Predict: 1.0
#           Else (feature 0 > 2756.5)
#            If (feature 3 in {0.0})
#             If (feature 11 in {1.0})
#              Predict: 1.0
#             Else (feature 11 not in {1.0})
#              If (feature 2 <= 4.5)
#               Predict: 1.0
#              Else (feature 2 > 4.5)
#               If (feature 0 <= 2993.5)
#                Predict: 1.0
#               Else (feature 0 > 2993.5)
#                Predict: 0.0
#            Else (feature 3 not in {0.0})
#             If (feature 16 in {1.0})
#              Predict: 0.0
#             Else (feature 16 not in {1.0})
#              If (feature 1 <= 2995.5)
#               Predict: 1.0
#              Else (feature 1 > 2995.5)
#               If (feature 2 <= -115.5)
#                If (feature 8 in {0.0})
#                 Predict: 0.0
#                Else (feature 8 not in {0.0})
#                 If (feature 1 <= 3024.5)
#                  Predict: 0.0
#                 Else (feature 1 > 3024.5)
#                  If (feature 2 <= -136.5)
#                   Predict: 1.0
#                  Else (feature 2 > -136.5)
#                   Predict: 0.0
#               Else (feature 2 > -115.5)
#                If (feature 10 in {1.0})
#                 Predict: 0.0
#                Else (feature 10 not in {1.0})
#                 If (feature 2 <= 20.5)
#                  Predict: 1.0
#                 Else (feature 2 > 20.5)
#                  Predict: 0.0
#          Else (feature 0 > 3024.0)
#           If (feature 1 <= 3128.5)
#            If (feature 10 in {1.0})
#             Predict: 1.0
#            Else (feature 10 not in {1.0})
#             Predict: 0.0
#           Else (feature 1 > 3128.5)
#            Predict: 1.0
#      Else (feature 2 > 28.5)
#       Predict: 0.0
#   Tree 4 (weight 1.0):
#     If (feature 10 in {1.0})
#      If (feature 0 <= 2796.5)
#       Predict: 1.0
#      Else (feature 0 > 2796.5)
#       Predict: 0.0
#     Else (feature 10 not in {1.0})
#      If (feature 26 in {1.0})
#       Predict: 0.0
#      Else (feature 26 not in {1.0})
#       If (feature 15 in {1.0})
#        Predict: 0.0
#       Else (feature 15 not in {1.0})
#        If (feature 0 <= 2881.5)
#         If (feature 11 in {1.0})
#          If (feature 0 <= 2631.5)
#           Predict: 0.0
#          Else (feature 0 > 2631.5)
#           If (feature 2 <= -9.5)
#            If (feature 2 <= -136.5)
#             If (feature 0 <= 2738.5)
#              Predict: 0.0
#             Else (feature 0 > 2738.5)
#              Predict: 1.0
#            Else (feature 2 > -136.5)
#             Predict: 1.0
#           Else (feature 2 > -9.5)
#            If (feature 0 <= 2868.5)
#             Predict: 0.0
#            Else (feature 0 > 2868.5)
#             Predict: 1.0
#         Else (feature 11 not in {1.0})
#          If (feature 13 in {1.0})
#           Predict: 1.0
#          Else (feature 13 not in {1.0})
#           If (feature 25 in {1.0})
#            Predict: 0.0
#           Else (feature 25 not in {1.0})
#            If (feature 0 <= 2811.5)
#             If (feature 1 <= 2700.5)
#              If (feature 1 <= 2366.5)
#               If (feature 5 in {1.0})
#                Predict: 0.0
#               Else (feature 5 not in {1.0
#
# *** WARNING: max output size exceeded, skipping output. ***
#
#                  Predict: 0.0
#                     Else (feature 0 > 2852.5)
#                      Predict: 1.0
#                   Else (feature 1 > 2761.5)
#                    Predict: 0.0
#                 Else (feature 8 not in {0.0})
#                  Predict: 0.0
#                Else (feature 2 > 155.5)
#                 If (feature 2 <= 342.5)
#                  If (feature 1 <= 2700.5)
#                   If (feature 10 in {0.0})
#                    If (feature 8 in {0.0})
#                     Predict: 0.0
#                    Else (feature 8 not in {0.0})
#                     If (feature 1 <= 2673.5)
#                      Predict: 0.0
#                     Else (feature 1 > 2673.5)
#                      If (feature 0 <= 2852.5)
#                       Predict: 1.0
#                      Else (feature 0 > 2852.5)
#                       Predict: 0.0
#                   Else (feature 10 not in {0.0})
#                    Predict: 0.0
#                  Else (feature 1 > 2700.5)
#                   If (feature 1 <= 2789.5)
#                    If (feature 1 <= 2761.5)
#                     If (feature 10 in {0.0})
#                      If (feature 8 in {1.0})
#                       Predict: 0.0
#                      Else (feature 8 not in {1.0})
#                       If (feature 16 in {1.0})
#                        Predict: 0.0
#                       Else (feature 16 not in {1.0})
#                        If (feature 2 <= 186.5)
#                         Predict: 0.0
#                        Else (feature 2 > 186.5)
#                         If (feature 0 <= 2934.5)
#                          Predict: 0.0
#                         Else (feature 0 > 2934.5)
#                          If (feature 1 <= 2719.5)
#                           Predict: 0.0
#                          Else (feature 1 > 2719.5)
#                           Predict: 1.0
#                     Else (feature 10 not in {0.0})
#                      If (feature 1 <= 2743.5)
#                       Predict: 0.0
#                      Else (feature 1 > 2743.5)
#                       Predict: 1.0
#                    Else (feature 1 > 2761.5)
#                     Predict: 0.0
#                   Else (feature 1 > 2789.5)
#                    If (feature 0 <= 2962.5)
#                     If (feature 3 in {1.0})
#                      Predict: 0.0
#                     Else (feature 3 not in {1.0})
#                      Predict: 1.0
#                    Else (feature 0 > 2962.5)
#                     Predict: 0.0
#                 Else (feature 2 > 342.5)
#                  Predict: 0.0
#              Else (feature 0 > 2993.5)
#               Predict: 0.0
#     Else (feature 1 > 2870.5)
#      If (feature 2 <= 4.5)
#       If (feature 11 in {1.0})
#        If (feature 0 <= 2738.5)
#         Predict: 0.0
#        Else (feature 0 > 2738.5)
#         Predict: 1.0
#       Else (feature 11 not in {1.0})
#        Predict: 1.0
#      Else (feature 2 > 4.5)
#       If (feature 8 in {0.0})
#        If (feature 21 in {1.0})
#         Predict: 1.0
#        Else (feature 21 not in {1.0})
#         Predict: 0.0
#       Else (feature 8 not in {0.0})
#        If (feature 2 <= 46.5)
#         If (feature 0 <= 3024.0)
#          Predict: 1.0
#         Else (feature 0 > 3024.0)
#          Predict: 0.0
#        Else (feature 2 > 46.5)
#         Predict: 0.0
#   Tree 14 (weight 1.0):
#     If (feature 15 in {1.0})
#      If (feature 0 <= 2673.5)
#       If (feature 1 <= 2643.5)
#        Predict: 0.0
#       Else (feature 1 > 2643.5)
#        Predict: 1.0
#      Else (feature 0 > 2673.5)
#       If (feature 1 <= 2761.5)
#        Predict: 0.0
#       Else (feature 1 > 2761.5)
#        Predict: 1.0
#     Else (feature 15 not in {1.0})
#      If (feature 11 in {1.0})
#       Predict: 1.0
#      Else (feature 11 not in {1.0})
#       If (feature 0 <= 2811.5)
#        If (feature 30 in {1.0})
#         Predict: 0.0
#        Else (feature 30 not in {1.0})
#         If (feature 4 in {1.0})
#          Predict: 1.0
#         Else (feature 4 not in {1.0})
#          If (feature 5 in {1.0})
#           If (feature 25 in {1.0})
#            Predict: 1.0
#           Else (feature 25 not in {1.0})
#            If (feature 27 in {1.0})
#             Predict: 0.0
#            Else (feature 27 not in {1.0})
#             If (feature 2 <= 71.5)
#              Predict: 1.0
#             Else (feature 2 > 71.5)
#              If (feature 26 in {1.0})
#               Predict: 0.0
#              Else (feature 26 not in {1.0})
#               If (feature 0 <= 2770.5)
#                Predict: 0.0
#               Else (feature 0 > 2770.5)
#                Predict: 1.0
#          Else (feature 5 not in {1.0})
#           If (feature 20 in {1.0})
#            If (feature 0 <= 1146.5)
#             Predict: 1.0
#            Else (feature 0 > 1146.5)
#             Predict: 0.0
#           Else (feature 20 not in {1.0})
#            If (feature 6 in {1.0})
#             Predict: 1.0
#            Else (feature 6 not in {1.0})
#             If (feature 0 <= 2143.0)
#              If (feature 16 in {1.0})
#               Predict: 1.0
#              Else (feature 16 not in {1.0})
#               If (feature 8 in {0.0})
#                If (feature 2 <= -32.5)
#                 Predict: 1.0
#                Else (feature 2 > -32.5)
#                 Predict: 0.0
#               Else (feature 8 not in {0.0})
#                Predict: 0.0
#             Else (feature 0 > 2143.0)
#              Predict: 1.0
#       Else (feature 0 > 2811.5)
#        Predict: 0.0
#   Tree 15 (weight 1.0):
#     If (feature 15 in {1.0})
#      If (feature 1 <= 2743.5)
#       Predict: 0.0
#      Else (feature 1 > 2743.5)
#       Predict: 1.0
#     Else (feature 15 not in {1.0})
#      If (feature 10 in {1.0})
#       Predict: 0.0
#      Else (feature 10 not in {1.0})
#       If (feature 20 in {1.0})
#        If (feature 2 <= -349.5)
#         Predict: 1.0
#        Else (feature 2 > -349.5)
#         Predict: 0.0
#       Else (feature 20 not in {1.0})
#        If (feature 30 in {1.0})
#         Predict: 0.0
#        Else (feature 30 not in {1.0})
#         If (feature 32 in {1.0})
#          Predict: 0.0
#         Else (feature 32 not in {1.0})
#          If (feature 17 in {1.0})
#           If (feature 2 <= 28.5)
#            Predict: 1.0
#           Else (feature 2 > 28.5)
#            Predict: 0.0
#          Else (feature 17 not in {1.0})
#           If (feature 21 in {1.0})
#            Predict: 1.0
#           Else (feature 21 not in {1.0})
#            If (feature 0 <= 2895.5)
#             If (feature 0 <= 2353.5)
#              If (feature 19 in {1.0})
#               Predict: 1.0
#              Else (feature 19 not in {1.0})
#               If (feature 13 in {1.0})
#                If (feature 1 <= 1145.5)
#                 Predict: 1.0
#                Else (feature 1 > 1145.5)
#                 Predict: 0.0
#               Else (feature 13 not in {1.0})
#                If (feature 3 in {1.0})
#                 Predict: 1.0
#                Else (feature 3 not in {1.0})
#                 If (feature 11 in {1.0})
#                  Predict: 1.0
#                 Else (feature 11 not in {1.0})
#                  If (feature 12 in {1.0})
#                   If (feature 1 <= 2366.5)
#                    If (feature 2 <= -79.5)
#                     Predict: 1.0
#                    Else (feature 2 > -79.5)
#                     Predict: 0.0
#                   Else (feature 1 > 2366.5)
#                    Predict: 1.0
#                  Else (feature 12 not in {1.0})
#                   Predict: 1.0
#             Else (feature 0 > 2353.5)
#              If (feature 5 in {1.0})
#               If (feature 2 <= 57.5)
#                If (feature 1 <= 2673.5)
#                 If (feature 18 in {1.0})
#                  Predict: 0.0
#                 Else (feature 18 not in {1.0})
#                  Predict: 1.0
#                Else (feature 1 > 2673.5)
#                 If (feature 2 <= -64.5)
#                  Predict: 1.0
#                 Else (feature 2 > -64.5)
#                  If (feature 0 <= 2673.5)
#                   Predict: 0.0
#                  Else (feature 0 > 2673.5)
#                   Predict: 1.0
#               Else (feature 2 > 57.5)
#                Predict: 0.0
#              Else (feature 5 not in {1.0})
#               Predict: 1.0
#            Else (feature 0 > 2895.5)
#             If (feature 4 in {1.0})
#              If (feature 2 <= 4.5)
#               Predict: 1.0
#              Else (feature 2 > 4.5)
#               If (feature 1 <= 2856.5)
#                If (feature 1 <= 1427.0)
#                 Predict: 1.0
#                Else (feature 1 > 1427.0)
#                 Predict: 0.0
#               Else (feature 1 > 2856.5)
#                Predict: 0.0
#             Else (feature 4 not in {1.0})
#              Predict: 0.0
#   Tree 16 (weight 1.0):
#     If (feature 1 <= 2774.5)
#      If (feature 0 <= 2770.5)
#       If (feature 3 in {0.0})
#        If (feature 27 in {1.0})
#         Predict: 1.0
#        Else (feature 27 not in {1.0})
#         If (feature 23 in {1.0})
#          Predict: 1.0
#         Else (feature 23 not in {1.0})
#          If (feature 2 <= -79.5)
#           Predict: 1.0
#          Else (feature 2 > -79.5)
#           If (feature 2 <= 71.5)
#            If (feature 2 <= -64.5)
#             Predict: 0.0
#            Else (feature 2 > -64.5)
#             If (feature 12 in {1.0})
#              If (feature 1 <= 2513.5)
#               If (feature 0 <= 2353.5)
#                Predict: 0.0
#               Else (feature 0 > 2353.5)
#                Predict: 1.0
#              Else (feature 1 > 2513.5)
#               Predict: 0.0
#             Else (feature 12 not in {1.0})
#              Predict: 1.0
#           Else (feature 2 > 71.5)
#            Predict: 0.0
#       Else (feature 3 not in {0.0})
#        If (feature 20 in {1.0})
#         Predict: 0.0
#        Else (feature 20 not in {1.0})
#         If (feature 0 <= 2697.5)
#          If (feature 10 in {1.0})
#           If (feature 2 <= 155.5)
#            Predict: 1.0
#           Else (feature 2 > 155.5)
#            Predict: 0.0
#          Else (feature 10 not in {1.0})
#           If (feature 1 <= 2474.5)
#            If (feature 2 <= -1.5)
#             Predict: 1.0
#            Else (feature 2 > -1.5)
#             Predict: 0.0
#           Else (feature 1 > 2474.5)
#            Predict: 1.0
#         Else (feature 0 > 2697.5)
#          If (feature 2 <= -9.5)
#           Predict: 1.0
#          Else (feature 2 > -9.5)
#           Predict: 0.0
#      Else (feature 0 > 2770.5)
#       If (feature 3 in {0.0})
#        If (feature 2 <= 57.5)
#         Predict: 1.0
#        Else (feature 2 > 57.5)
#         If (feature 12 in {1.0})
#          Predict: 1.0
#         Else (feature 12 not in {1.0})
#          Predict: 0.0
#       Else (feature 3 not in {0.0})
#        Predict: 0.0
#     Else (feature 1 > 2774.5)
#      If (feature 0 <= 2783.5)
#       If (feature 0 <= 2673.5)
#        Predict: 1.0
#       Else (feature 0 > 2673.5)
#        If (feature 2 <= 4.5)
#         If (feature 9 in {1.0})
#          Predict: 1.0
#         Else (feature 9 not in {1.0})
#          If (feature 1 <= 3024.5)
#           Predict: 1.0
#          Else (feature 1 > 3024.5)
#           If (feature 0 <= 2738.5)
#            Predict: 1.0
#           Else (feature 0 > 2738.5)
#            Predict: 0.0
#        Else (feature 2 > 4.5)
#         Predict: 0.0
#      Else (feature 0 > 2783.5)
#       If (feature 0 <= 2895.5)
#        If (feature 1 <= 2886.5)
#         If (feature 1 <= 2789.5)
#          If (feature 4 in {0.0})
#           Predict: 0.0
#          Else (feature 4 not in {0.0})
#           If (feature 0 <= 2852.5)
#            Predict: 0.0
#           Else (feature 0 > 2852.5)
#            Predict: 1.0
#         Else (feature 1 > 2789.5)
#          Predict: 1.0
#        Else (feature 1 > 2886.5)
#         If (feature 2 <= -115.5)
#          If (feature 2 <= -136.5)
#           If (feature 9 in {1.0})
#            Predict: 0.0
#           Else (feature 9 not in {1.0})
#            Predict: 1.0
#          Else (feature 2 > -136.5)
#           Predict: 1.0
#         Else (feature 2 > -115.5)
#          If (feature 16 in {1.0})
#           Predict: 0.0
#          Else (feature 16 not in {1.0})
#           If (feature 0 <= 2839.5)
#            If (feature 8 in {0.0})
#             If (feature 9 in {0.0})
#              Predict: 0.0
#             Else (feature 9 not in {0.0})
#              Predict: 1.0
#            Else (feature 8 not in {0.0})
#             Predict: 1.0
#           Else (feature 0 > 2839.5)
#            Predict: 1.0
#       Else (feature 0 > 2895.5)
#        If (feature 16 in {1.0})
#         If (feature 2 <= -17.5)
#          Predict: 1.0
#         Else (feature 2 > -17.5)
#          Predict: 0.0
#        Else (feature 16 not in {1.0})
#         If (feature 9 in {1.0})
#          If (feature 2 <= 28.5)
#           Predict: 1.0
#          Else (feature 2 > 28.5)
#           Predict: 0.0
#         Else (feature 9 not in {1.0})
#          Predict: 0.0
#   Tree 17 (weight 1.0):
#     If (feature 5 in {1.0})
#      If (feature 18 in {1.0})
#       Predict: 1.0
#      Else (feature 18 not in {1.0})
#       If (feature 2 <= 36.5)
#        If (feature 0 <= 2471.5)
#         If (feature 2 <= -9.5)
#          If (feature 2 <= -115.5)
#           Predict: 1.0
#          Else (feature 2 > -115.5)
#           If (feature 2 <= -64.5)
#            If (feature 2 <= -79.5)
#             If (feature 0 <= 2353.5)
#              If (feature 1 <= 2366.5)
#               Predict: 1.0
#              Else (feature 1 > 2366.5)
#               Predict: 0.0
#             Else (feature 0 > 2353.5)
#              Predict: 1.0
#            Else (feature 2 > -79.5)
#             Predict: 0.0
#           Else (feature 2 > -64.5)
#            Predict: 1.0
#         Else (feature 2 > -9.5)
#          Predict: 0.0
#        Else (feature 0 > 2471.5)
#         If (feature 1 <= 2673.5)
#          If (feature 1 <= 2643.5)
#           Predict: 1.0
#          Else (feature 1 > 2643.5)
#           Predict: 0.0
#         Else (feature 1 > 2673.5)
#          Predict: 1.0
#       Else (feature 2 > 36.5)
#        If (feature 32 in {1.0})
#         Predict: 0.0
#        Else (feature 32 not in {1.0})
#         If (feature 14 in {1.0})
#          Predict: 0.0
#         Else (feature 14 not in {1.0})
#          If (feature 2 <= 90.5)
#           If (feature 1 <= 2596.5)
#            If (feature 0 <= 2552.5)
#             Predict: 0.0
#            Else (feature 0 > 2552.5)
#             If (feature 1 <= 2551.5)
#              Predict: 1.0
#             Else (feature 1 > 2551.5)
#              If (feature 15 in {1.0})
#               Predict: 0.0
#              Else (feature 15 not in {1.0})
#               Predict: 1.0
#           Else (feature 1 > 2596.5)
#            Predict: 0.0
#          Else (feature 2 > 90.5)
#           Predict: 0.0
#     Else (feature 5 not in {1.0})
#      If (feature 1 <= 2774.5)
#       If (feature 0 <= 2783.5)
#        If (feature 13 in {1.0})
#         If (feature 2 <= -32.5)
#          Predict: 1.0
#         Else (feature 2 > -32.5)
#          Predict: 0.0
#        Else (feature 13 not in {1.0})
#         If (feature 1 <= 2700.5)
#          If (feature 9 in {1.0})
#           Predict: 0.0
#          Else (feature 9 not in {1.0})
#           If (feature 1 <= 2643.5)
#            If (feature 2 <= 12.5)
#             If (feature 4 in {1.0})
#              Predict: 1.0
#             Else (feature 4 not in {1.0})
#              If (feature 0 <= 2471.5)
#               If (feature 24 in {1.0})
#                Predict: 1.0
#               Else (feature 24 not in {1.0})
#                If (feature 2 <= -32.5)
#                 If (feature 1 <= 2142.0)
#                  Predict: 1.0
#                 Else (feature 1 > 2142.0)
#                  If (feature 19 in {1.0})
#                   Predict: 1.0
#                  Else (feature 19 not in {1.0})
#                   If (feature 1 <= 2439.5)
#                    If (feature 2 <= -40.5)
#                     Predict: 1.0
#                    Else (feature 2 > -40.5)
#                     Predict: 0.0
#                   Else (feature 1 > 2439.5)
#                    Predict: 1.0
#                Else (feature 2 > -32.5)
#                 Predict: 1.0
#              Else (feature 0 > 2471.5)
#               Predict: 1.0
#            Else (feature 2 > 12.5)
#             If (feature 1 <= 2596.5)
#              If (feature 19 in {1.0})
#               Predict: 0.0
#              Else (feature 19 not in {1.0})
#               If (feature 16 in {1.0})
#                If (feature 1 <= 2142.0)
#                 Predict: 0.0
#                Else (feature 1 > 2142.0)
#                 Predict: 1.0
#               Else (feature 16 not in {1.0})
#                Predict: 0.0
#             Else (feature 1 > 2596.5)
#              Predict: 1.0
#           Else (feature 1 > 2643.5)
#            Predict: 0.0
#         Else (feature 1 > 2700.5)
#          If (feature 0 <= 2697.5)
#           If (feature 1 <= 2719.5)
#            Predict: 1.0
#           Else (feature 1 > 2719.5)
#            If (feature 2 <= -115.5)
#             Predict: 1.0
#            Else (feature 2 > -115.5)
#             If (feature 4 in {1.0})
#              Predict: 0.0
#             Else (feature 4 not in {1.0})
#              Predict: 1.0
#          Else (feature 0 > 2697.5)
#           If (feature 1 <= 2743.5)
#            If (feature 4 in {1.0})
#             Predict: 1.0
#            Else (feature 4 not in {1.0})
#             Predict: 0.0
#           Else (feature 1 > 2743.5)
#            If (feature 0 <= 2738.5)
#             If (feature 0 <= 2715.5)
#              Predict: 1.0
#             Else (feature 0 > 2715.5)
#              If (feature 2 <= -32.5)
#               Predict: 1.0
#              Else (feature 2 > -32.5)
#               If (feature 1 <= 2761.5)
#                Predict: 1.0
#               Else (feature 1 > 2761.5)
#                Predict: 0.0
#            Else (feature 0 > 2738.5)
#             Predict: 1.0
#       Else (feature 0 > 2783.5)
#        Predict: 0.0
#      Else (feature 1 > 2774.5)
#       If (feature 21 in {1.0})
#        Predict: 1.0
#       Else (feature 21 not in {1.0})
#        If (feature 9 in {1.0})
#         Predict: 1.0
#        Else (feature 9 not in {1.0})
#         If (feature 10 in {1.0})
#          Predict: 1.0
#         Else (feature 10 not in {1.0})
#          If (feature 4 in {1.0})
#           If (feature 2 <= 12.5)
#            If (feature 2 <= -25.5)
#             Predict: 1.0
#            Else (feature 2 > -25.5)
#             If (feature 2 <= -9.5)
#              Predict: 0.0
#             Else (feature 2 > -9.5)
#              Predict: 1.0
#           Else (feature 2 > 12.5)
#            Predict: 0.0
#          Else (feature 4 not in {1.0})
#           If (feature 2 <= -25.5)
#            Predict: 1.0
#           Else (feature 2 > -25.5)
#            If (feature 8 in {0.0})
#             Predict: 0.0
#            Else (feature 8 not in {0.0})
#             If (feature 0 <= 2796.5)
#              Predict: 1.0
#             Else (feature 0 > 2796.5)
#              Predict: 0.0
#   Tree 18 (weight 1.0):
#     If (feature 18 in {1.0})
#      Predict: 1.0
#     Else (feature 18 not in {1.0})
#      If (feature 23 in {1.0})
#       Predict: 1.0
#      Else (feature 23 not in {1.0})
#       If (feature 13 in {1.0})
#        If (feature 2 <= -32.5)
#         Predict: 1.0
#        Else (feature 2 > -32.5)
#         If (feature 1 <= 2142.0)
#          Predict: 0.0
#         Else (feature 1 > 2142.0)
#          Predict: 1.0
#       Else (feature 13 not in {1.0})
#        If (feature 1 <= 2774.5)
#         If (feature 15 in {1.0})
#          If (feature 0 <= 2595.5)
#           Predict: 1.0
#          Else (feature 0 > 2595.5)
#           If (feature 2 <= -52.5)
#            Predict: 1.0
#           Else (feature 2 > -52.5)
#            Predict: 0.0
#         Else (feature 15 not in {1.0})
#          If (feature 0 <= 2770.5)
#           If (feature 19 in {1.0})
#            Predict: 1.0
#           Else (feature 19 not in {1.0})
#            If (feature 4 in {1.0})
#             If (feature 1 <= 2700.5)
#              If (feature 2 <= -17.5)
#               Predict: 1.0
#              Else (feature 2 > -17.5)
#               If (feature 0 <= 2432.5)
#                If (feature 1 <= 2142.0)
#                 Predict: 0.0
#                Else (feature 1 > 2142.0)
#                 Predict: 1.0
#               Else (feature 0 > 2432.5)
#                Predict: 0.0
#             Else (feature 1 > 2700.5)
#              Predict: 1.0
#            Else (feature 4 not in {1.0})
#             If (feature 32 in {1.0})
#              Predict: 0.0
#             Else (feature 32 not in {1.0})
#              If (feature 6 in {1.0})
#               Predict: 1.0
#              Else (feature 6 not in {1.0})
#               If (feature 1 <= 2474.5)
#                If (feature 12 in {1.0})
#                 Predict: 0.0
#                Else (feature 12 not in {1.0})
#                 If (feature 1 <= 1427.0)
#                  If (feature 2 <= 28.5)
#                   Predict: 1.0
#                  Else (feature 2 > 28.5)
#                   Predict: 0.0
#                 Else (feature 1 > 1427.0)
#                  If (feature 20 in {1.0})
#                   If (feature 2 <= -349.5)
#                    Predict: 1.0
#                   Else (feature 2 > -349.5)
#                    Predict: 0.0
#                  Else (feature 20 not in {1.0})
#                   If (feature 3 in {0.0})
#                    If (feature 1 <= 2142.0)
#                     Predict: 0.0
#                    Else (feature 1 > 2142.0)
#                     If (feature 2 <= -32.5)
#                      Predict: 1.0
#                     Else (feature 2 > -32.5)
#                      Predict: 0.0
#                   Else (feature 3 not in {0.0})
#                    Predict: 1.0
#               Else (feature 1 > 2474.5)
#                If (feature 16 in {1.0})
#                 If (feature 2 <= -159.5)
#                  Predict: 1.0
#                 Else (feature 2 > -159.5)
#                  Predict: 0.0
#                Else (feature 16 not in {1.0})
#                 If (feature 12 in {1.0})
#                  If (feature 1 <= 2673.5)
#                   Predict: 1.0
#                  Else (feature 1 > 2673.5)
#                   If (feature 2 <= -64.5)
#                    Predict: 1.0
#                   Else (feature 2 > -64.5)
#                    Predict: 0.0
#                 Else (feature 12 not in {1.0})
#                  Predict: 1.0
#          Else (feature 0 > 2770.5)
#           If (feature 0 <= 2852.5)
#            If (feature 4 in {1.0})
#             Predict: 0.0
#            Else (feature 4 not in {1.0})
#             If (feature 12 in {1.0})
#              Predict: 1.0
#             Else (feature 12 not in {1.0})
#              Predict: 0.0
#           Else (feature 0 > 2852.5)
#            Predict: 0.0
#        Else (feature 1 > 2774.5)
#         If (feature 12 in {1.0})
#          Predict: 1.0
#         Else (feature 12 not in {1.0})
#          If (feature 11 in {1.0})
#           Predict: 1.0
#          Else (feature 11 not in {1.0})
#           If (feature 21 in {1.0})
#            Predict: 0.0
#           Else (feature 21 not in {1.0})
#            If (feature 0 <= 2811.5)
#             Predict: 1.0
#            Else (feature 0 > 2811.5)
#             If (feature 10 in {1.0})
#              If (feature 2 <= -159.5)
#               Predict: 1.0
#              Else (feature 2 > -159.5)
#               Predict: 0.0
#             Else (feature 10 not in {1.0})
#              If (feature 3 in {0.0})
#               If (feature 2 <= 90.5)
#                Predict: 1.0
#               Else (feature 2 > 90.5)
#                Predict: 0.0
#              Else (feature 3 not in {0.0})
#               If (feature 2 <= 4.5)
#                Predict: 1.0
#               Else (feature 2 > 4.5)
#                Predict: 0.0
#   Tree 19 (weight 1.0):
#     If (feature 3 in {0.0})
#      If (feature 17 in {1.0})
#       Predict: 0.0
#      Else (feature 17 not in {1.0})
#       If (feature 5 in {1.0})
#        If (feature 26 in {1.0})
#         Predict: 0.0
#        Else (feature 26 not in {1.0})
#         If (feature 18 in {1.0})
#          Predict: 1.0
#         Else (feature 18 not in {1.0})
#          If (feature 2 <= -79.5)
#           Predict: 1.0
#          Else (feature 2 > -79.5)
#           Predict: 0.0
#       Else (feature 5 not in {1.0})
#        If (feature 1 <= 2870.5)
#         If (feature 9 in {0.0})
#          If (feature 19 in {1.0})
#           If (feature 2 <= -64.5)
#            Predict: 1.0
#           Else (feature 2 > -64.5)
#            Predict: 0.0
#          Else (feature 19 not in {1.0})
#           If (feature 11 in {0.0})
#            If (feature 6 in {0.0})
#             Predict: 0.0
#            Else (feature 6 not in {0.0})
#             Predict: 1.0
#           Else (feature 11 not in {0.0})
#            Predict: 0.0
#         Else (feature 9 not in {0.0})
#          Predict: 0.0
#        Else (feature 1 > 2870.5)
#         If (feature 0 <= 2868.5)
#          If (feature 2 <= -17.5)
#           Predict: 1.0
#          Else (feature 2 > -17.5)
#           Predict: 0.0
#         Else (feature 0 > 2868.5)
#          If (feature 1 <= 3128.5)
#           If (feature 1 <= 3024.5)
#            If (feature 1 <= 2995.5)
#             Predict: 0.0
#            Else (feature 1 > 2995.5)
#             Predict: 1.0
#           Else (feature 1 > 3024.5)
#            If (feature 9 in {1.0})
#             Predict: 0.0
#            Else (feature 9 not in {1.0})
#             If (feature 2 <= 57.5)
#              Predict: 1.0
#             Else (feature 2 > 57.5)
#              Predict: 0.0
#          Else (feature 1 > 3128.5)
#           If (feature 11 in {0.0})
#            If (feature 9 in {0.0})
#             Predict: 0.0
#            Else (feature 9 not in {0.0})
#             Predict: 1.0
#           Else (feature 11 not in {0.0})
#            Predict: 1.0
#     Else (feature 3 not in {0.0})
#      Predict: 1.0

# %%
rf_preds = rf_model.transform(validation)

# %%
evaluator = MulticlassClassificationEvaluator()\
                .setLabelCol("label")\
                .setPredictionCol("prediction")

# %%
evaluator.setMetricName('accuracy')
print("Accuracy : %s" % evaluator.evaluate(rf_preds))
# Out:
# Accuracy : 0.6820040899795501

# %%
bceval = BinaryClassificationEvaluator()
print (bceval.getMetricName() +":" + str(bceval.evaluate(rf_preds)))
# Out:
# areaUnderROC:0.7583279162909683

# %%
bceval.setMetricName("areaUnderPR")
print (bceval.getMetricName() +":" + str(bceval.evaluate(rf_preds)))
# Out:
# areaUnderPR:0.7728006863442387

# %%
metric_name = "f1"
metrics = MulticlassClassificationEvaluator()\
                .setLabelCol("label")\
                .setPredictionCol("prediction")
metrics.setMetricName(metric_name) 

metrics.evaluate(rf_preds)
# Out:
# Out[30]: 0.6807248394719112

# %% [markdown]
# ## Random Forest (Black Elo, White Elo, Elo Diff, Time Class, Time Control)

# %%
# Use to get model accuracy
evaluator = MulticlassClassificationEvaluator()\
                .setLabelCol("label")\
                .setPredictionCol("prediction")
evaluator.setMetricName('accuracy')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
rf = RandomForestClassifier()
paramGrid = ParamGridBuilder()\
                .addGrid(rf.numTrees, [10, 20, 30, 40, 50])\
                .addGrid(rf.minInstancesPerNode, [1, 2, 3, 4, 5, 10])\
                .addGrid(rf.maxDepth, [2,3,4,5,10,15,20,30])\
                .build()

cv = CrossValidator(estimator=rf, 
                    evaluator=evaluator, 
                    numFolds=5, 
                    estimatorParamMaps=paramGrid)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Fit a cross-validated Random Forest model on training data
cvmodel = cv.fit(train)
rfpredicts = cvmodel.bestModel.transform(validation)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/spark/python/pyspark/ml/util.py:800: UserWarning: Cannot find mlflow module. To enable MLflow logging, install mlflow from PyPI.
#   warnings.warn(_MLflowInstrumentation._NO_MLFLOW_WARNING)
# </div>

# %%
print("Best Max Depth : %s" % cvmodel.bestModel.getMaxDepth)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Best Max Depth : &lt;bound method _DecisionTreeParams.getMaxDepth of RandomForestClassificationModel: uid=RandomForestClassifier_2c330fee3841, numTrees=30, numClasses=2, numFeatures=35&gt;
# </div>

# %%
print("Best Num Trees : %s" % cvmodel.bestModel.getNumTrees)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Best Num Trees : 30
# </div>

# %%
print("Accuracy : %s" % evaluator.evaluate(rfpredicts))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Accuracy : 0.7006237006237006
# </div>

# %%
bceval = BinaryClassificationEvaluator()
print (bceval.getMetricName() +":" + str(bceval.evaluate(rfpredicts)))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">areaUnderROC:0.7427193798856072
# </div>

# %%
bceval.setMetricName("areaUnderPR")
print (bceval.getMetricName() +":" + str(bceval.evaluate(rfpredicts)))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">areaUnderPR:0.7403933403387412
# </div>

# %%
metric_name = "f1"
metrics = MulticlassClassificationEvaluator()\
                .setLabelCol("label")\
                .setPredictionCol("prediction")
metrics.setMetricName(metric_name) 

metrics.evaluate(rfpredicts)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[39]: 0.696650021738361</div>

# %% [markdown]
# ## Random Forest (Black Elo, White Elo)

# %%
va = VectorAssembler(outputCol="features", inputCols=["Black Elo","White Elo"])
va_df = va.transform(df_elo).select("features", "result_int").withColumnRenamed("result_int", "label")

# %%
splits = va_df.randomSplit([0.8, 0.2])

train = splits[0].cache()
validation = splits[1].cache()

# %%
evaluator = MulticlassClassificationEvaluator()\
                .setLabelCol("label")\
                .setPredictionCol("prediction")

# %%
rf = RandomForestClassifier()
paramGrid = ParamGridBuilder()\
                .addGrid(rf.numTrees, [10, 20, 30, 40, 50])\
                .addGrid(rf.minInstancesPerNode, [1, 2, 3, 4, 5, 10])\
                .addGrid(rf.maxDepth, [2,3,4,5,10,15,20,30])\
                .build()

cv = CrossValidator(estimator=rf, 
                    evaluator=evaluator, 
                    numFolds=5, 
                    estimatorParamMaps=paramGrid)

# %%
# Fit a cross-validated Random Forest model on training data
cvmodel = cv.fit(train)
rfpredicts = cvmodel.bestModel.transform(validation)

# %%
print("Best Max Depth : %s" % cvmodel.bestModel.getMaxDepth)
print("Best Num Trees : %s" % cvmodel.bestModel.getNumTrees)
# Out:
# Best Max Depth : <bound method _DecisionTreeParams.getMaxDepth of RandomForestClassificationModel: uid=RandomForestClassifier_1953c16dd364, numTrees=20, numClasses=2, numFeatures=2>
# Best Num Trees : 20

# %%
print("Accuracy : %s" % evaluator.evaluate(rfpredicts))
bceval = BinaryClassificationEvaluator()
print (bceval.getMetricName() +":" + str(bceval.evaluate(rfpredicts)))
bceval.setMetricName("areaUnderPR")
print (bceval.getMetricName() +":" + str(bceval.evaluate(rfpredicts)))
# Out:
# Accuracy : 0.6841491306900274
# areaUnderROC:0.7509996424808062
# areaUnderPR:0.7938620582628833

# %%
metric_name = "f1"
metrics = MulticlassClassificationEvaluator()\
                .setLabelCol("label")\
                .setPredictionCol("prediction")
metrics.setMetricName(metric_name) 

metrics.evaluate(rfpredicts)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[54]: 0.6844404679860532</div>

# %% [markdown]
# ## Random Forest (Elo Diff)

# %%
va = VectorAssembler(outputCol="features", inputCols=["elo_diff"])
va_df = va.transform(df_elo).select("features", "result_int").withColumnRenamed("result_int", "label")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
splits = va_df.randomSplit([0.8, 0.2])

train = splits[0].cache()
validation = splits[1].cache()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
evaluator = MulticlassClassificationEvaluator()\
                .setLabelCol("label")\
                .setPredictionCol("prediction")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
rf = RandomForestClassifier()
paramGrid = ParamGridBuilder()\
                .addGrid(rf.numTrees, [10, 20, 30, 40, 50])\
                .addGrid(rf.minInstancesPerNode, [1, 2, 3, 4, 5, 10])\
                .addGrid(rf.maxDepth, [2,3,4,5,10,15,20,30])\
                .build()

cv = CrossValidator(estimator=rf, 
                    evaluator=evaluator, 
                    numFolds=5, 
                    estimatorParamMaps=paramGrid)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
# Fit a cross-validated Random Forest model on training data
cvmodel = cv.fit(train)
rfpredicts = cvmodel.bestModel.transform(validation)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print("Best Max Depth : %s" % cvmodel.bestModel.getMaxDepth)
print("Best Num Trees : %s" % cvmodel.bestModel.getNumTrees)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Best Max Depth : &lt;bound method _DecisionTreeParams.getMaxDepth of RandomForestClassificationModel: uid=RandomForestClassifier_fbb08a4eb5a7, numTrees=30, numClasses=2, numFeatures=1&gt;
# Best Num Trees : 30
# </div>

# %%
print("Accuracy : %s" % evaluator.evaluate(rfpredicts))
bceval = BinaryClassificationEvaluator()
print (bceval.getMetricName() +":" + str(bceval.evaluate(rfpredicts)))
bceval.setMetricName("areaUnderPR")
print (bceval.getMetricName() +":" + str(bceval.evaluate(rfpredicts)))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Accuracy : 0.7061369740889494
# areaUnderROC:0.7527195011646428
# areaUnderPR:0.7413051435098182
# </div>

# %%
metric_name = "f1"
metrics = MulticlassClassificationEvaluator()\
                .setLabelCol("label")\
                .setPredictionCol("prediction")
metrics.setMetricName(metric_name) 

metrics.evaluate(rfpredicts)
